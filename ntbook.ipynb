# %%
# !pip install fastai2>=0.0.11 
# !pip install voila
# !jupyter serverextension enable voila --sys-prefix
#ipywidgets  nbdev>=0.2.12 pandas
# Out:
# Requirement already satisfied: voila in /opt/conda/lib/python3.6/site-packages (0.1.21)
# Requirement already satisfied: nbconvert<6,>=5.5.0 in /opt/conda/lib/python3.6/site-packages (from voila) (5.6.1)
# Requirement already satisfied: jupyterlab-pygments<0.2,>=0.1.0 in /opt/conda/lib/python3.6/site-packages (from voila) (0.1.0)
# Requirement already satisfied: jupyter-server<0.2.0,>=0.1.0 in /opt/conda/lib/python3.6/site-packages (from voila) (0.1.1)
# Requirement already satisfied: pygments<3,>=2.4.1 in /opt/conda/lib/python3.6/site-packages (from voila) (2.6.1)
# Requirement already satisfied: async-generator in /opt/conda/lib/python3.6/site-packages (from voila) (1.10)
# Requirement already satisfied: jinja2>=2.4 in /opt/conda/lib/python3.6/site-packages (from nbconvert<6,>=5.5.0->voila) (2.11.1)
# Requirement already satisfied: nbformat>=4.4 in /opt/conda/lib/python3.6/site-packages (from nbconvert<6,>=5.5.0->voila) (5.0.4)
# Requirement already satisfied: testpath in /opt/conda/lib/python3.6/site-packages (from nbconvert<6,>=5.5.0->voila) (0.4.4)
# Requirement already satisfied: jupyter-core in /opt/conda/lib/python3.6/site-packages (from nbconvert<6,>=5.5.0->voila) (4.6.1)
# Requirement already satisfied: traitlets>=4.2 in /opt/conda/lib/python3.6/site-packages (from nbconvert<6,>=5.5.0->voila) (4.3.3)
# Requirement already satisfied: entrypoints>=0.2.2 in /opt/conda/lib/python3.6/site-packages (from nbconvert<6,>=5.5.0->voila) (0.3)
# Requirement already satisfied: defusedxml in /opt/conda/lib/python3.6/site-packages (from nbconvert<6,>=5.5.0->voila) (0.6.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/conda/lib/python3.6/site-packages (from nbconvert<6,>=5.5.0->voila) (1.4.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in /opt/conda/lib/python3.6/site-packages (from nbconvert<6,>=5.5.0->voila) (0.8.4)
# Requirement already satisfied: bleach in /opt/conda/lib/python3.6/site-packages (from nbconvert<6,>=5.5.0->voila) (3.1.0)
# Requirement already satisfied: tornado>=4 in /opt/conda/lib/python3.6/site-packages (from jupyter-server<0.2.0,>=0.1.0->voila) (5.0.2)
# Requirement already satisfied: ipython-genutils in /opt/conda/lib/python3.6/site-packages (from jupyter-server<0.2.0,>=0.1.0->voila) (0.2.0)
# Requirement already satisfied: jupyter-client>=5.3.1 in /opt/conda/lib/python3.6/site-packages (from jupyter-server<0.2.0,>=0.1.0->voila) (6.1.2)
# Requirement already satisfied: prometheus-client in /opt/conda/lib/python3.6/site-packages (from jupyter-server<0.2.0,>=0.1.0->voila) (0.7.1)
# Requirement already satisfied: pyzmq>=17 in /opt/conda/lib/python3.6/site-packages (from jupyter-server<0.2.0,>=0.1.0->voila) (18.1.1)
# Requirement already satisfied: ipykernel in /opt/conda/lib/python3.6/site-packages (from jupyter-server<0.2.0,>=0.1.0->voila) (5.1.1)
# Requirement already satisfied: Send2Trash in /opt/conda/lib/python3.6/site-packages (from jupyter-server<0.2.0,>=0.1.0->voila) (1.5.0)
# Requirement already satisfied: terminado>=0.8.1 in /opt/conda/lib/python3.6/site-packages (from jupyter-server<0.2.0,>=0.1.0->voila) (0.8.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/lib/python3.6/site-packages (from jinja2>=2.4->nbconvert<6,>=5.5.0->voila) (1.1.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /opt/conda/lib/python3.6/site-packages (from nbformat>=4.4->nbconvert<6,>=5.5.0->voila) (3.2.0)
# Requirement already satisfied: six in /opt/conda/lib/python3.6/site-packages (from traitlets>=4.2->nbconvert<6,>=5.5.0->voila) (1.14.0)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.6/site-packages (from traitlets>=4.2->nbconvert<6,>=5.5.0->voila) (4.4.2)
# Requirement already satisfied: webencodings in /opt/conda/lib/python3.6/site-packages (from bleach->nbconvert<6,>=5.5.0->voila) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.1 in /opt/conda/lib/python3.6/site-packages (from jupyter-client>=5.3.1->jupyter-server<0.2.0,>=0.1.0->voila) (2.8.1)
# Requirement already satisfied: ipython>=5.0.0 in /opt/conda/lib/python3.6/site-packages (from ipykernel->jupyter-server<0.2.0,>=0.1.0->voila) (7.13.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /opt/conda/lib/python3.6/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert<6,>=5.5.0->voila) (1.5.0)
# Requirement already satisfied: attrs>=17.4.0 in /opt/conda/lib/python3.6/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert<6,>=5.5.0->voila) (19.3.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /opt/conda/lib/python3.6/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert<6,>=5.5.0->voila) (0.16.0)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.6/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert<6,>=5.5.0->voila) (46.1.3.post20200330)
# Requirement already satisfied: jedi>=0.10 in /opt/conda/lib/python3.6/site-packages (from ipython>=5.0.0->ipykernel->jupyter-server<0.2.0,>=0.1.0->voila) (0.15.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /opt/conda/lib/python3.6/site-packages (from ipython>=5.0.0->ipykernel->jupyter-server<0.2.0,>=0.1.0->voila) (3.0.4)
# Requirement already satisfied: backcall in /opt/conda/lib/python3.6/site-packages (from ipython>=5.0.0->ipykernel->jupyter-server<0.2.0,>=0.1.0->voila) (0.1.0)
# Requirement already satisfied: pickleshare in /opt/conda/lib/python3.6/site-packages (from ipython>=5.0.0->ipykernel->jupyter-server<0.2.0,>=0.1.0->voila) (0.7.5)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /opt/conda/lib/python3.6/site-packages (from ipython>=5.0.0->ipykernel->jupyter-server<0.2.0,>=0.1.0->voila) (4.8.0)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.6/site-packages (from importlib-metadata; python_version < "3.8"->jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert<6,>=5.5.0->voila) (2.2.0)
# Requirement already satisfied: parso>=0.5.2 in /opt/conda/lib/python3.6/site-packages (from jedi>=0.10->ipython>=5.0.0->ipykernel->jupyter-server<0.2.0,>=0.1.0->voila) (0.5.2)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.6/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.0.0->ipykernel->jupyter-server<0.2.0,>=0.1.0->voila) (0.1.9)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/lib/python3.6/site-packages (from pexpect; sys_platform != "win32"->ipython>=5.0.0->ipykernel->jupyter-server<0.2.0,>=0.1.0->voila) (0.6.0)
# Enabling: voila
# - Writing config: /opt/conda/etc/jupyter
#     - Validating...
#       voila 0.1.21 OK

# %%
from fastai2.learner import load_learner
github_path = Path()/'export.pkl'
kaggle_path = Path("..")/'input/export.pkl'
learn_inf = load_learner(github_path)

# %%
# from PIL import Image
# import requests
# from io import BytesIO
# url = "https://assets.vg247.com/current/2015/10/Fallout4PipBoyNews2.png"

# url=input()
# response = requests.get(url)
# img = Image.open(BytesIO(response.content))
# img_resized = img.resize((128, 128), Image.ANTIALIAS)
# img_array = np.asarray(img_resized)
# print(img_array.shape)

# %%
from fastai2.vision.widgets import *
from fastai2.vision.all import *

btn_upload = widgets.FileUpload()

# %%
btn_run = widgets.Button(description='Classify')
out_pl = widgets.Output()
lbl_pred = widgets.Label()

# %%
def on_click(change): 
    img = PILImage.create(btn_upload.data[-1])
    
    out_pl.clear_output()
    with out_pl: display(img.to_thumb(128,128))
#     display(out_pl)
# display(img.resize((300, 300), Image.ANTIALIAS))
    cls, index, probs = learn_inf.predict(img)
    classes = learn_inf.dls.vocab
    lbl_base = widgets.Label()
    lbl_base.value="Probabilities"
#     display(lbl_base)
    results = []
    for c, p in zip(classes, probs):
        results.append(f"{c}:{p.item()}")
        
    lbl_pred.value = str(results)
#         display(lbl_pred)
    # allDone()

# %%
btn_run.on_click(on_click)

# %%
VBox([widgets.Label('Select your image!'), 
      btn_upload, btn_run, out_pl, lbl_pred])
# Out:
# VBox(children=(Label(value='Select your image!'), FileUpload(value={'WIN_20191210_13_24_13_Pro.jpg': {'metadat…
